# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavi-Punnam/NASSCOM-Lab/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}
# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
raw_sensor_data = []
for i in range(1, 101):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    device_id=f"DEV{i:03d}"
    device_type=random.choice(DEVICE_TYPES)
    location=random.choice(LOCATIONS)
    min_val,max_val=READING_RANGES[device_type]
    value=round(random.uniform(min_val,max_val),2)
    reading=(timestamp,device_id,device_type,location,value)
    raw_sensor_data.append(reading)
print(f"Successfully generated {len(raw_sensor_data)} readings.")
print("Here is a sample of the first 3 readings:")
for reading in raw_sensor_data[:3]:
    print(reading)
# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
temperature_reading=[]
for timestamp,device_id,device_type,location,value in raw_sensor_data:
  if device_type=="Temperature_Sensor":
    reading_dict={'timestamp':timestamp,'device_id':device_id,'location':location,'temperature_celsius':value}
    temperature_reading.append(reading_dict)
# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
unique_locations = set()
for reading in raw_sensor_data:
    loc = reading[3]
    unique_locations.add(loc)
#1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
device_values = {}
for device_type in DEVICE_TYPES:
    device_values[device_type] = []
for timestamp, device_id, device_type, location, value in raw_sensor_data:
    device_values[device_type].append(value)
device_stats = {}
for device_type, values in device_values.items():
    min_val = min(values)
    max_val = max(values)
    device_stats[device_type] = (min_val, max_val)

print("\n--- Task 1.4 Output ---")
for device_type, min_max in device_stats.items():
    print(f"{device_type}: Min = {min_max[0]}, Max = {min_max[1]}")
#1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]
print("substring_1:", substring_1)
print("substring_2:", substring_2)

# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("\n--- Task 1.5.3 Output ---")
print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:     ", device_type_suffix)
# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")
# 2.1 Write a function `get_readings_by_location(readings_list, target_location)
def get_readings_by_location(readings_list, target_location):
    filtered_readings = []

    for timestamp, device_id, device_type, location, value in readings_list:
        if location == target_location:
            # We add the original reading tuple to our filtered list
            reading = (timestamp, device_id, device_type, location, value)
            filtered_readings.append(reading)

    return filtered_readings
# 2.2 Write a function `calculate_average_temperature(temp_data_list)`

def calculate_average_temperature(temp_data_list):
    # Guard clause: Return 0.0 if list is empty
    if not temp_data_list:
        return 0.0

    total_temp = 0.0
    for reading in temp_data_list:
        total_temp += reading['temperature_celsius']

    avg_temp = total_temp / len(temp_data_list)
    return round(avg_temp, 2)


# Let's test the function using your list from Task 1.2!
avg_temp = calculate_average_temperature(temperature_reading)
print(f"Average Temperature: {avg_temp}°C")
# 2.3 Write a function `generate_report_line(reading_dict)`
def generate_report_line(reading_dict):
    timestamp = reading_dict['timestamp']
    device_id = reading_dict['device_id']
    location = reading_dict['location']
    temperature_celsius = reading_dict['temperature_celsius']
    return f"[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

print(generate_report_line(temperature_reading[0]))
print("\n--- Task 3: Core Library Usage ---")
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Your code for Task 3.2 here:
# --- Task 3: Core Libraries (datetime, random, os) ---
print("\n--- Task 3: Working with Datetime ---")

# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
first_ts_str = raw_sensor_data[0][0]
last_ts_str = raw_sensor_data[-1][0]

date_format = "%Y-%m-%d %H:%M:%S"
first_dt = datetime.datetime.strptime(first_ts_str, date_format)
last_dt = datetime.datetime.strptime(last_ts_str, date_format)

duration = last_dt - first_dt

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"First timestamp: {first_ts_str}")
print(f"Last timestamp:  {last_ts_str}")
print(f"Duration: {days} days, {hours} hours, and {minutes} minutes")
# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

random_values = [random.randint(100, 200) for _ in range(5)]
print("Random Values:", random_values)
# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_reading:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")
# 4.2 Read 'sensor_reports/temperature_report.txt' into 'read_report_lines' and print first 3 lines.

with open('sensor_reports/temperature_report.txt', 'r') as f:
    read_report_lines = f.readlines()

print("\n--- First 3 Lines ---")
for line in read_report_lines[:3]:
    print(line.strip())
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Successfully generated 100 readings.
# Here is a sample of the first 3 readings:
# ('2026-07-20 05:10:17', 'DEV001', 'Temperature_Sensor', 'Lab2', 24.71)
# ('2026-07-20 05:10:17', 'DEV002', 'Humidity_Sensor', 'OfficeA', 49.95)
# ('2026-07-20 05:10:17', 'DEV003', 'Humidity_Sensor', 'OfficeA', 79.95)
#
# --- Task 1.4 Output ---
# Temperature_Sensor: Min = 18.18, Max = 29.52
# Humidity_Sensor: Min = 30.96, Max = 79.95
# Pressure_Sensor: Min = 980.19, Max = 1029.56
# Light_Sensor: Min = 123.36, Max = 999.05
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# substring_1: Programming
# substring_2: nohtyP
#
# --- Task 1.5.3 Output ---
# 5th Reading Device Type: Pressure_Sensor
# Device Type Suffix:      Sensor
#
# --- Task 2: Function Definitions and Usage ---
# Average Temperature: 23.06°C
# [2026-07-20 05:10:17] Device DEV001 at Lab2: 24.71°C
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.
#
# --- Task 3: Working with Datetime ---
# First timestamp: 2026-07-20 05:10:17
# Last timestamp:  2026-07-20 05:10:17
# Duration: 0 days, 0 hours, and 0 minutes
# Random Values: [119, 100, 147, 116, 164]
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# --- First 3 Lines ---
# [2026-07-20 05:10:17] Device DEV001 at Lab2: 24.71°C
# [2026-07-20 05:10:17] Device DEV006 at Lab2: 23.82°C
# [2026-07-20 05:10:17] Device DEV009 at Lab1: 20.87°C
