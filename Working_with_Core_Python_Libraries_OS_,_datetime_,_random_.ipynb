# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavi-Punnam/NASSCOM-Lab/blob/main/Working_with_Core_Python_Libraries_OS_%2C_datetime_%2C_random_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print("Current directory:",os.getcwd())
print("files and folders:",os.listdir())
os.mkdir("demo_folder")
os.rename("demo_folder","new_folder")
os.rmdir("new_folder")
# Out:
# Current directory: /content
# files and folders: ['.config', 'sample_data']

# %%
from datetime import datetime,date,timedelta
now=datetime.now()
print("Now:",now)
today=date.today()
print("Today's date:",today)
dob=date(2007,10,19)
print("DOB:",dob)
yesterday=today-timedelta(days=1)
tomorrow=today+timedelta(days=1)
print("Yesterday:",yesterday)
print("Tomorrow:",tomorrow)
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted date time:",formatted)
# Out:
# Now: 2026-07-13 06:19:04.033333
# Today's date: 2026-07-13
# DOB: 2007-10-19
# Yesterday: 2026-07-12
# Tomorrow: 2026-07-14
# Formatted date time: 13-07-2026 06:19:04

# %%
import random
print("Random Int:",random.randint(1,100))
print("Random Float:",random.random())
colors=['red','green','blue']
print("Random Color:",random.choice(colors))
random.shuffle(colors)
print("Shuffled list:",colors)
print("Sample:",random.sample(range(1,50),5))
# Out:
# Random Int: 88
# Random Float: 0.14554975214742116
# Random Color: blue
# Shuffled list: ['red', 'blue', 'green']
# Sample: [45, 28, 26, 22, 44]

# %%
from collections import Counter
fruits=['apple','banana','apple','orange','banana','apple']
count=Counter(fruits)
print("Fruit count:",count)
# Out:
# Fruit count: Counter({'apple': 3, 'banana': 2, 'orange': 1})
